# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient

client = MultiServerMCPClient(
    {
        "travel_server": {
                "transport": "streamable_http",
                "url": "https://mcp.kiwi.com"
            }
    }
)

tools = await client.get_tools()

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

agent = create_agent(
    "gpt-5-nano",
    tools=tools,
    checkpointer=InMemorySaver(),
    system_prompt="You are a travel agent. No follow up questions."
)

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = await agent.ainvoke(
    {"messages": [HumanMessage(content="Get me a direct flight from San Francisco to Tokyo on March 31st")]},
    config
    )

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Get me a direct flight from San Francisco to Tokyo on March 31st', additional_kwargs={}, response_metadata={}, id='b85b1f4a-8786-4a6c-ad96-3e1108b291fb'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 827, 'prompt_tokens': 1229, 'total_tokens': 2056, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 768, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CyQFJfFjL2eF4e2UVDdDoe6CQWRHJ', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019bc3cd-d426-7973-a54a-4e3d28d1a6e9-0', tool_calls=[{'name': 'search-flight', 'args': {'flyFrom': 'San Francisco', 'flyTo': 'Tokyo', 'departureDate': '31/03/2026', 'passengers': {'adults': 1}, 'cabinClass': 'M', 'sort': 'date'}, 'id': 'call_MC0MsWnNSS7YK7wMc4Sbyx6r', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1229, 'output_tokens': 827, 'total_tokens': 2056, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 768}}),
#               ToolMessage(content=[{'type': 'text', 'text': '[\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-03-31T07:25:00.000Z",\n      "local": "2026-03-31T00:25:00.000"\n    },\n    "arrival": {\n      "utc": "2026-04-01T10:40:00.000Z",\n      "local": "2026-04-01T19:40:00.000"\n    },\n    "totalDurationInSeconds": 98100,\n    "durationInSeconds": 98100,\n    "price": 446,\n    "deepLink": "https://on.kiwi.com/c3MjIC",\n    "currency": "EUR",\n    "layovers": [\n      {\n        "at": "TPE",\n        "city": "Taipei",\n        "cityCode": "TPE",\n        "arrival": {\n          "utc": "2026-03-31T21:15:00.000Z",\n          "local": "2026-04-01T05:15:00.000"\n        },\n        "departure": {\n          "utc": "2026-04-01T07:20:00.000Z",\n          "local": "2026-04-01T15:20:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-03-31T07:50:00.000Z",\n      "local": "2026-03-31T00:50:00.000"\n    },\n    "arrival": {\n      "utc": "2026-04-01T10:40:00.000Z",\n      "local": "2026-04-01T19:40:00.000"\n    },\n    "totalDurationInSeconds": 96600,\n    "durationInSeconds": 96600,\n    "price": 446,\n    "deepLink": "https://on.kiwi.com/RBkFkU",\n    "currency": "EUR",\n    "layovers": [\n      {\n        "at": "TPE",\n        "city": "Taipei",\n        "cityCode": "TPE",\n        "arrival": {\n          "utc": "2026-03-31T21:40:00.000Z",\n          "local": "2026-04-01T05:40:00.000"\n        },\n        "departure": {\n          "utc": "2026-04-01T07:20:00.000Z",\n          "local": "2026-04-01T15:20:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-03-31T07:50:00.000Z",\n      "local": "2026-03-31T00:50:00.000"\n    },\n    "arrival": {\n      "utc": "2026-04-01T03:55:00.000Z",\n      "local": "2026-04-01T12:55:00.000"\n    },\n    "totalDurationInSeconds": 72300,\n    "durationInSeconds": 72300,\n    "price": 500,\n    "deepLink": "https://on.kiwi.com/LR8P2d",\n    "currency": "EUR",\n    "layovers": [\n      {\n        "at": "TPE",\n        "city": "Taipei",\n        "cityCode": "TPE",\n        "arrival": {\n          "utc": "2026-03-31T21:25:00.000Z",\n          "local": "2026-04-01T05:25:00.000"\n        },\n        "departure": {\n          "utc": "2026-04-01T00:30:00.000Z",\n          "local": "2026-04-01T08:30:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-03-31T07:50:00.000Z",\n      "local": "2026-03-31T00:50:00.000"\n    },\n    "arrival": {\n      "utc": "2026-04-01T06:05:00.000Z",\n      "local": "2026-04-01T15:05:00.000"\n    },\n    "totalDurationInSeconds": 80100,\n    "durationInSeconds": 80100,\n    "price": 500,\n    "deepLink": "https://on.kiwi.com/oicPym",\n    "currency": "EUR",\n    "layovers": [\n      {\n        "at": "TPE",\n        "city": "Taipei",\n        "cityCode": "TPE",\n        "arrival": {\n          "utc": "2026-03-31T21:25:00.000Z",\n          "local": "2026-04-01T05:25:00.000"\n        },\n        "departure": {\n          "utc": "2026-04-01T02:40:00.000Z",\n          "local": "2026-04-01T10:40:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-03-31T16:59:00.000Z",\n      "local": "2026-03-31T09:59:00.000"\n    },\n    "arrival": {\n      "utc": "2026-04-01T07:00:00.000Z",\n      "local": "2026-04-01T16:00:00.000"\n    },\n    "totalDurationInSeconds": 50460,\n    "durationInSeconds": 50460,\n    "price": 412,\n    "deepLink": "https://on.kiwi.com/ ...
#               AIMessage(content='Direct flights are not available in the current search for SFO to Tokyo on March 31. Here are the best one-stop options I found:\n\nCheapest options (price: 409–412 EUR)\n- Route: SFO → SEA → NRT\n  - Schedule: 31/03 09:59 → 01/04 20:00 (11h 15m)\n  - Cabin: Economy\n  - Price: 409 EUR\n  - Book: https://on.kiwi.com/JWCuDV\n\n- Route: SFO → SEA → NRT\n  - Schedule: 31/03 12:20 → 01/04 15:25 (11h 5m)\n  - Cabin: Economy\n  - Price: 412 EUR\n  - Book: https://on.kiwi.com/YQLIKX\n\nShortest duration options (11h 5m / 11h 15m)\n- Route: SFO → SEA → NRT\n  - Schedule: 31/03 12:20 → 01/04 15:25 (11h 5m)\n  - Cabin: Economy\n  - Price: 412 EUR\n  - Book: https://on.kiwi.com/YQLIKX\n\n- Route: SFO → SEA → NRT\n  - Schedule: 31/03 09:59 → 01/04 20:00 (11h 15m)\n  - Cabin: Economy\n  - Price: 409 EUR\n  - Book: https://on.kiwi.com/JWCuDV\n\nRecommendation: If a direct flight is essential, I can search for nearby dates or alternate Tokyo airports (NRT or HND) to find nonstop options. Fun fact: Tokyo is home to the world’s busiest pedestrian scramble at Shibuya Crossing, a must-see slice of urban energy. Have a wonderful trip!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 12700, 'prompt_tokens': 5837, 'total_tokens': 18537, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 12288, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CyQFS3x2CWJQBODkF6aXpQAq5t1PE', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019bc3cd-f95c-7452-904c-373cb49d4392-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 5837, 'output_tokens': 12700, 'total_tokens': 18537, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 12288}})]}

# %%
print(response["messages"][-1].content)
# Out:
# Direct flights are not available in the current search for SFO to Tokyo on March 31. Here are the best one-stop options I found:
#
# Cheapest options (price: 409–412 EUR)
# - Route: SFO → SEA → NRT
#   - Schedule: 31/03 09:59 → 01/04 20:00 (11h 15m)
#   - Cabin: Economy
#   - Price: 409 EUR
#   - Book: https://on.kiwi.com/JWCuDV
#
# - Route: SFO → SEA → NRT
#   - Schedule: 31/03 12:20 → 01/04 15:25 (11h 5m)
#   - Cabin: Economy
#   - Price: 412 EUR
#   - Book: https://on.kiwi.com/YQLIKX
#
# Shortest duration options (11h 5m / 11h 15m)
# - Route: SFO → SEA → NRT
#   - Schedule: 31/03 12:20 → 01/04 15:25 (11h 5m)
#   - Cabin: Economy
#   - Price: 412 EUR
#   - Book: https://on.kiwi.com/YQLIKX
#
# - Route: SFO → SEA → NRT
#   - Schedule: 31/03 09:59 → 01/04 20:00 (11h 15m)
#   - Cabin: Economy
#   - Price: 409 EUR
#   - Book: https://on.kiwi.com/JWCuDV
#
# Recommendation: If a direct flight is essential, I can search for nearby dates or alternate Tokyo airports (NRT or HND) to find nonstop options. Fun fact: Tokyo is home to the world’s busiest pedestrian scramble at Shibuya Crossing, a must-see slice of urban energy. Have a wonderful trip!
