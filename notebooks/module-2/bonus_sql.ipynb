# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_community.utilities import SQLDatabase

db = SQLDatabase.from_uri("sqlite:///resources/Chinook.db")

# %%
from langchain.tools import tool

@tool
def sql_query(query: str) -> str:

    """Obtain information from the database using SQL queries"""

    try:
        return db.run(query)
    except Exception as e:
        return f"Error: {e}"

sql_query.invoke("SELECT * FROM Artist LIMIT 10")
# Out:
# "[(1, 'AC/DC'), (2, 'Accept'), (3, 'Aerosmith'), (4, 'Alanis Morissette'), (5, 'Alice In Chains'), (6, 'Antônio Carlos Jobim'), (7, 'Apocalyptica'), (8, 'Audioslave'), (9, 'BackBeat'), (10, 'Billy Cobham')]"

# %%
from langchain.agents import create_agent

agent = create_agent(
    model="gpt-5-nano",
    tools=[sql_query]
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Who is the most popular artist beginning with 'S' in this database?")

response = agent.invoke(
    {"messages": [question]}
)

# %%
from pprint import pprint

pprint(response['messages'])
# Out:
# [HumanMessage(content="Who is the most popular artist beginning with 'S' in this database?", additional_kwargs={}, response_metadata={}, id='6fcc1f55-132a-44f9-80da-dac32ed4cabb'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 680, 'prompt_tokens': 142, 'total_tokens': 822, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 640, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D1OVdXZcoTPaSK82pAJ850pxe5SRS', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019bee05-c141-7d21-86c2-918f79f0067f-0', tool_calls=[{'name': 'sql_query', 'args': {'query': "SELECT name FROM artists WHERE name LIKE 'S%' ORDER BY popularity DESC LIMIT 1;"}, 'id': 'call_vbs7hhJYsxFQ3RjWc28HYTzH', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 142, 'output_tokens': 680, 'total_tokens': 822, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 640}}),
#  ToolMessage(content="Error: (sqlite3.OperationalError) no such table: artists\n[SQL: SELECT name FROM artists WHERE name LIKE 'S%' ORDER BY popularity DESC LIMIT 1;]\n(Background on this error at: https://sqlalche.me/e/20/e3q8)", name='sql_query', id='9215e6b9-d382-483f-90d8-4f0de4a5bbf4', tool_call_id='call_vbs7hhJYsxFQ3RjWc28HYTzH'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 288, 'prompt_tokens': 245, 'total_tokens': 533, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 256, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D1OVjAr4aGsTgueks98dgnkkkSeww', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019bee05-d71f-7cc3-809f-a14764b767b5-0', tool_calls=[{'name': 'sql_query', 'args': {'query': "SELECT name FROM sqlite_master WHERE type='table';"}, 'id': 'call_ta7H5TpwQGpefCw8jilmKkfl', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 245, 'output_tokens': 288, 'total_tokens': 533, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 256}}),
#  ToolMessage(content="[('Album',), ('Artist',), ('Customer',), ('Employee',), ('Genre',), ('Invoice',), ('InvoiceLine',), ('MediaType',), ('Playlist',), ('PlaylistTrack',), ('Track',)]", name='sql_query', id='0c44b387-afdc-4442-ae99-5a54efd5e7d0', tool_call_id='call_ta7H5TpwQGpefCw8jilmKkfl'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 29, 'prompt_tokens': 330, 'total_tokens': 359, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D1OVmtOUFUALbbxtquw463691uAjU', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019bee05-e365-7391-b386-176321e30cde-0', tool_calls=[{'name': 'sql_query', 'args': {'query': 'SELECT name FROM Artist ORDER BY Popularity DESC LIMIT 1;'}, 'id': 'call_O2s4vyApxyAQAFj3l3SD7Q8N', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 330, 'output_tokens': 29, 'total_tokens': 359, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  ToolMessage(content='Error: (sqlite3.OperationalError) no such column: Popularity\n[SQL: SELECT name FROM Artist ORDER BY Popularity DESC LIMIT 1;]\n(Background on this error at: https://sqlalche.me/e/20/e3q8)', name='sql_query', id='54b95121-7d6c-45ff-91b3-403df42699c9', tool_call_id='call_O2s4vyApxyAQAFj3l3SD7Q8N'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 739, 'prompt_tokens': 424, 'total_tokens': 1163, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 640, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D1OVmbum3iqxCVT24QAQ1gF0p2DsA', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019bee05-e638-7c73-ac50-48cc2d330bc0-0', tool_calls=[{'name': 'sql_query', 'args': {'query': 'SELECT ar.Name AS ArtistName, SUM(il.UnitPrice * il.Quantity) AS Revenue\nFROM Artist ar\nJOIN Album al ON al.ArtistId = ar.ArtistId\nJOIN Track t ON t.AlbumId = al.AlbumId\nJOIN InvoiceLine il ON il.TrackId = t.TrackId\nGROUP BY ar.Name\nORDER BY Revenue DESC\nLIMIT 1;'}, 'id': 'call_gWjyhE53OnUDP8syiL1vcGUK', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 424, 'output_tokens': 739, 'total_tokens': 1163, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 640}}),
#  ToolMessage(content="[('Iron Maiden', 138.6)]", name='sql_query', id='01a518fa-6975-49e3-b73d-c7d8a2c9b4bd', tool_call_id='call_gWjyhE53OnUDP8syiL1vcGUK'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 876, 'prompt_tokens': 538, 'total_tokens': 1414, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 768, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D1OVtxHlHZ8mNzcgzTBpqLj6o7xUi', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019bee06-0093-70e0-b5ec-98007625dcd3-0', tool_calls=[{'name': 'sql_query', 'args': {'query': "SELECT ar.Name AS ArtistName, SUM(il.UnitPrice * il.Quantity) AS Revenue\nFROM Artist ar\nJOIN Album al ON al.ArtistId = ar.ArtistId\nJOIN Track t ON t.AlbumId = al.AlbumId\nJOIN InvoiceLine il ON il.TrackId = t.TrackId\nWHERE ar.Name LIKE 'S%'\nGROUP BY ar.Name\nORDER BY Revenue DESC\nLIMIT 1;"}, 'id': 'call_A4tavthc9S9Hu4e4PChVXocQ', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 538, 'output_tokens': 876, 'total_tokens': 1414, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 768}}),
#  ToolMessage(content="[('Smashing Pumpkins', 23.759999999999998)]", name='sql_query', id='9b68db8e-3b90-4957-8b12-4906d386e7e4', tool_call_id='call_A4tavthc9S9Hu4e4PChVXocQ'),
#  AIMessage(content="Smashing Pumpkins. They have the highest total revenue among artists whose names start with 'S' in this database, with a revenue of 23.76. If you want a different popularity metric (e.g., number of tracks sold, total units), I can compute that too.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 451, 'prompt_tokens': 667, 'total_tokens': 1118, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 384, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D1OW0wWI3cgca649eWK2tkZzRXqBX', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019bee06-1bd6-78e3-b8b7-6e06f34511ab-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 667, 'output_tokens': 451, 'total_tokens': 1118, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 384}})]

# %%
print(response["messages"][-3].tool_calls[0]['args']['query'])
# Out:
# SELECT ar.Name AS ArtistName, SUM(il.UnitPrice * il.Quantity) AS Revenue
# FROM Artist ar
# JOIN Album al ON al.ArtistId = ar.ArtistId
# JOIN Track t ON t.AlbumId = al.AlbumId
# JOIN InvoiceLine il ON il.TrackId = t.TrackId
# WHERE ar.Name LIKE 'S%'
# GROUP BY ar.Name
# ORDER BY Revenue DESC
# LIMIT 1;

# %%
pprint(response["messages"][-1].content)
# Out:
# ('Smashing Pumpkins. They have the highest total revenue among artists whose '
#  "names start with 'S' in this database, with a revenue of 23.76. If you want "
#  'a different popularity metric (e.g., number of tracks sold, total units), I '
#  'can compute that too.')
